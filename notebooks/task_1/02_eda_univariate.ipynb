# %%
import sys
sys.path.append("../../")
from src.config import RAW_DATA_PATH
from src.data_loader import load_raw_data

# %% [markdown]
# # data loading

# %%
df = load_raw_data(RAW_DATA_PATH)
# Out:
# c:\Users\user\OneDrive\Documents\Data Science\insurance-risk-modeling\notebooks\task_1\../..\src\data_loader.py:10: DtypeWarning: Columns (32) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(path)

# %% [markdown]
# # Analysis

# %%
from src.task_1.eda.univariate import analyze_numeric_features, analyze_categorical_features, analyze_datetime_features

# %% [markdown]
# ## numeric analysis

# %%
analyze_numeric_features(df)
# Out:
# {'UnderwrittenCoverID': {'stats': count    569760.000000
#   mean     114793.834344
#   std       60150.634394
#   min         286.000000
#   25%       74389.000000
#   50%      112079.000000
#   75%      145019.000000
#   max      301175.000000
#   Name: UnderwrittenCoverID, dtype: float64,
#   'missing': np.int64(0)},
#  'PolicyID': {'stats': count    569760.000000
#   mean       8871.465087
#   std        5086.571036
#   min          49.000000
#   25%        5570.000000
#   50%        7703.000000
#   75%       12032.000000
#   max       23246.000000
#   Name: PolicyID, dtype: float64,
#   'missing': np.int64(0)},
#  'PostalCode': {'stats': count    569760.000000
#   mean       2646.399215
#   std        2431.170158
#   min           1.000000
#   25%         472.000000
#   50%        2000.000000
#   75%        4061.000000
#   max        9870.000000
#   Name: PostalCode, dtype: float64,
#   'missing': np.int64(0)},
#  'mmcode': {'stats': count    5.696950e+05
# ...

# %% [markdown]
# ## categorical analysis

# %%
analyze_categorical_features(df)
# Out:
# c:\Users\user\OneDrive\Documents\Data Science\insurance-risk-modeling\notebooks\task_1\../..\src\task_1\eda\univariate.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_values.values, y=top_values.index, palette="viridis")
# c:\Users\user\OneDrive\Documents\Data Science\insurance-risk-modeling\notebooks\task_1\../..\src\task_1\eda\univariate.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_values.values, y=top_values.index, palette="viridis")
# c:\Users\user\OneDrive\Documents\Data Science\insurance-risk-modeling\notebooks\task_1\../..\src\task_1\eda\univariate.py:55: FutureWarning:
#
# ...

# %% [markdown]
# ## datetime analysis

# %%
analyze_datetime_features(df)
# Out:
# {}
